# %%
import pandas as pd 
import numpy as np

# %%
a = pd.read_csv("/home/student/Downloads/Salary_Data.csv")
a
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
a['Age'].mean()
# Out:
# np.float64(33.62085944494181)

# %%
a['Age'].median()
# Out:
# 32.0

# %%
a['Age'].min()
# Out:
# 21.0

# %%
a['Age'].max()
# Out:
# 62.0

# %%
a['Age'].std()
# Out:
# 7.614632626251171

# %%
a['Salary'].mean()
# Out:
# np.float64(115326.96477086132)

# %%
a['Salary'].median()
# Out:
# 115000.0

# %%
a['Salary'].min()
# Out:
# 350.0

# %%
a['Salary'].max()
# Out:
# 250000.0

# %%
a['Salary'].std()
# Out:
# 52786.183910682936

# %%
grp1 = a.groupby('Age')['Salary'].sum()

# %%
grp1
# Out:
# Age
# 21.0      450000.0
# 22.0      493664.0
# 23.0     4907969.0
# 24.0    12252540.0
# 25.0    18099430.0
# 26.0    25917999.0
# 27.0    40032721.0
# 28.0    36096218.0
# 29.0    38079549.0
# 30.0    45305876.0
# 31.0    41634852.0
# 32.0    42295563.0
# 33.0    50715256.0
# 34.0    40808175.0
# 35.0    23873167.0
# 36.0    37674155.0
# 37.0    22922556.0
# 38.0    20589650.0
# 39.0    23270669.0
# 40.0    13787395.0
# 41.0    20025388.0
# 42.0    27447636.0
# 43.0    26134685.0
# 44.0    20225378.0
# 45.0    24528138.0
# 46.0    17466721.0
# 47.0     8401255.0
# 48.0    18886937.0
# 49.0    17200236.0
# 50.0    16794791.0
# 51.0     6010682.0
# 52.0     5441252.0
# 53.0     1265646.0
# 54.0    12907505.0
# 55.0     3175715.0
# 56.0     2162354.0
# 57.0     1592944.0
# 58.0     1370008.0
# 60.0      930662.0
# 61.0      400000.0
# 62.0     1000000.0
# Name: Salary, dtype: float64

# %%
a["Age Group"] = pd.cut(
    a["Age"],
    bins=[20, 30, 40, 50, 62],
    labels=["20-30","31-40","41-50","51-62"],
)

# %%
a
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary Age Group
# 0                     5.0   90000.0     31-40
# 1                     3.0   65000.0     20-30
# 2                    15.0  150000.0     41-50
# ...
